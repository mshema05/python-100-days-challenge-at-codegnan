# %%
ph_book = {}

def add_contact(name: str, number: int):
    # check if name exists
    if name not in ph_book:
        ph_book[name] = number
        print("Contact saved")
    else:
        print("Name already exists")

# update mobile number
def update_number(name: str, number: int):
    if name not in ph_book:
        print("Contact not found")
    else:
        ph_book[name] = number
        print("Mobile number updated")

# delete contact
def delete_contact(name: str):
    if name in ph_book:
        ph_book.pop(name)
        print("Contact deleted")
    else:
        print("Contact not found")

# get contact by name
def get_contact(name: str):
    if name in ph_book:
        print(f"The contact number is: {ph_book[name]}")
    else:
        print("Contact not found")

# print all contacts
def all_contacts():
    if not ph_book:
        print("No contacts in phone book")
        return
    for name, number in ph_book.items():
        print(f"{name} : {number}")
if __name__ == '__main__':
    print("Welcome to Contact Book")

    while True:
        print("\n1. Add Contact")
        print("2. Update Contact")
        print("3. Delete Contact")
        print("4. Search Contact")
        print("5. Show All Contacts")
        print("6. Exit")

        choice = input("Enter your choice: ")

        if choice == '1':
            name = input("Enter name: ")
            number = int(input("Enter number: "))
            add_contact(name, number)

        elif choice == '2':
            name = input("Enter name: ")
            number = int(input("Enter new number: "))
            update_number(name, number)

        elif choice == '3':
            name = input("Enter name: ")
            delete_contact(name)

        elif choice == '4':
            name = input("Enter name: ")
            get_contact(name)

        elif choice == '5':
            all_contacts()

        elif choice == '6':
            print("Thank you! Exiting...")
            break

        else:
            print("Invalid choice. Try again.")
# Out:
# Welcome to Contact Book
#
# 1. Add Contact
# 2. Update Contact
# 3. Delete Contact
# 4. Search Contact
# 5. Show All Contacts
# 6. Exit
# Enter your choice:  1
# Enter name:  hema
# Enter number:  90526299
# Contact saved
#
# 1. Add Contact
# 2. Update Contact
# 3. Delete Contact
# 4. Search Contact
# 5. Show All Contacts
# 6. Exit
# Enter your choice:  2
# Enter name:  hema m
# Enter new number:  90543396645
# Contact not found
#
# 1. Add Contact
# 2. Update Contact
# 3. Delete Contact
# 4. Search Contact
# 5. Show All Contacts
# 6. Exit
# Enter your choice:  4
# Enter name:  hema m
# Contact not found
#
# 1. Add Contact
# 2. Update Contact
# 3. Delete Contact
# 4. Search Contact
# 5. Show All Contacts
# 6. Exit
# Enter your choice:  4
# Enter name:  hema
# The contact number is: 90526299
#
# 1. Add Contact
# 2. Update Contact
# 3. Delete Contact
# 4. Search Contact
# 5. Show All Contacts
# 6. Exit
# Enter your choice:  5
# hema : 90526299
#
# 1. Add Contact
# 2. Update Contact
# 3. Delete Contact
# 4. Search Contact
# 5. Show All Contacts
# 6. Exit
# Enter your choice:  6
# Thank you! Exiting...
